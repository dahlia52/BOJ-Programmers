# %% [markdown]
# <a href="https://colab.research.google.com/github/dahlia52/BAEKJOON/blob/main/9_2%EC%B0%A8%EC%9B%90_%EB%B0%B0%EC%97%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.acmicpc.net/step/2

# %% [markdown]
# - 2738번 행렬 덧셈

# %% [markdown]
# N*M크기의 두 행렬 A와 B가 주어졌을 때, 두 행렬을 더하는 프로그램을 작성하시오.

# %%
n,m = map(int, input().split())
list1 = []
for i in range(2*n):
  val = list(map(int, input().split()))
  list1.append(val)
for i in range(n):
  for j in range(m):
    print(list1[i][j] + list1[i+n][j], end=" ")
  print()
# Out:
# 2 4
# 1 2 3 4
# 5 6 7 8
# 3 2 1 5
# 4 3 4 3
# 4 4 4 9
# 9 9 11 11

# %% [markdown]
# - 2566번 최댓값

# %% [markdown]
# <그림 1>과 같이 9×9 격자판에 쓰여진 81개의 자연수 또는 0이 주어질 때, 이들 중 최댓값을 찾고 그 최댓값이 몇 행 몇 열에 위치한 수인지 구하는 프로그램을 작성하시오.
#
# 예를 들어, 다음과 같이 81개의 수가 주어지면 이들 중 최댓값은 90이고, 이 값은 5행 7열에 위치한다.

# %%
maxi, row, col = -1, 0, 0
for i in range(9):
  val = list(map(int, input().split()))
  if max(val) > maxi:
    maxi = max(val)
    row = i+1
    col = val.index(maxi)+1
print(maxi)
print(row, col)
# Out:
# 3 23 85 34 17 74 25 52 65
# 10 7 39 42 88 52 14 72 63
# 87 42 18 78 53 45 18 84 53
# 34 28 64 85 12 16 75 36 55
# 21 77 45 35 28 75 90 76 1
# 25 87 65 15 28 11 37 28 74
# 65 27 75 41 7 89 78 64 39
# 47 47 70 45 23 65 3 41 44
# 87 13 82 38 31 12 29 29 80
# 90
# 5 7

# %% [markdown]
# - 오답 요인) 모든 입력값이 0일 것을 대비하여 maxi 초기값을 0이 아닌 -1로 설정!

# %%
maxi, row, col = -1, 0, 0
for i in range(9):
  val = list(map(int, input().split()))
  for j in range(9):
    if val[j] > maxi:
      maxi = val[j]
      row = i+1
      col = j+1
print(maxi)
print(row, col)
# Out:
# 3 23 85 34 17 74 25 52 65
# 10 7 39 42 88 52 14 72 63
# 87 42 18 78 53 45 18 84 53
# 34 28 64 85 12 16 75 36 55
# 21 77 45 35 28 75 90 76 1
# 25 87 65 15 28 11 37 28 74
# 65 27 75 41 7 89 78 64 39
# 47 47 70 45 23 65 3 41 44
# 87 13 82 38 31 12 29 29 80
# 90
# 5 7

# %% [markdown]
# - 2563번 색종이

# %% [markdown]
# 가로, 세로의 크기가 각각 100인 정사각형 모양의 흰색 도화지가 있다. 이 도화지 위에 가로, 세로의 크기가 각각 10인 정사각형 모양의 검은색 색종이를 색종이의 변과 도화지의 변이 평행하도록 붙인다. 이러한 방식으로 색종이를 한 장 또는 여러 장 붙인 후 색종이가 붙은 검은 영역의 넓이를 구하는 프로그램을 작성하시오.
#
#
#
# 예를 들어 흰색 도화지 위에 세 장의 검은색 색종이를 그림과 같은 모양으로 붙였다면 검은색 영역의 넓이는 260이 된다.

# %%
n = int(input())
paper = []
sum1 = 0
for i in range(100):
  paper.append(list(0 for j in range(100)))
for i in range(n):
  x, y = map(int, input().split())
  for k in range(10):
    for j in range(10):
      paper[x+k][y+j] = 1
for pap in paper:
  sum1 += sum(pap)
print(sum1)
# Out:
# 2
# 0 0
# 0 0
# 100
